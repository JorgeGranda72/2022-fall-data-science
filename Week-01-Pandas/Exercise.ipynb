# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %%
print("hello World")
# Out:
# hello World

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here

df = pd.read_csv('data/listings.csv')

# %%
df.shape
# Out:
# (46527, 16)

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 

price_condition = df['price'] < 100
df.low_price = df[price_condition]
df.low_price.shape
# Out:
# (22778, 16)

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.

bk_condition = df["neighbourhood_group"] == "Brooklyn"
df_bk = df[bk_condition]
#df_bk.shape
print(len(df_bk))
# Out:
# 18632

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.
condition_100 = df_bk['price'] < 100
print(len(df_bk[condition_100]))
# Out:
# 10473

# %%
df_bk.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
host_name_list = ['Michael', 'David', 'John', 'Daniel']
name_condition = df.host_name.isin(host_name_list)
df_host_list = df[name_condition]
print(len(df_host_list))
# Out:
# 1258

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before.

c1 = df['neighbourhood'] == 'Williamsburg'
prices = df['price']
#df['is_in_williamsburg'] = np.where( c1, prices + 100, prices)

df['is_in_williamsburg'] = np.where( c1, df['price'] + 100, df['price'])

#df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.head(20)
# Out:
#       id                                               name  host_id  \
# 0   2595                              Skylit Midtown Castle     2845
# 1   3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2   5121                                    BlissArtsSpace!     7356
# 3   5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4   5178                   Large Furnished Room Near B'way　     8967
# 5   5203                 Cozy Clean Guest Room - Family Apt     7490
# 6   5238                 Cute & Cozy Lower East Side 1 bdrm     7549
# 7   5552            Spacious river view in the West Village     8380
# 8   5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
# 9   6021  Wonderful Guest Bedroom in Manhattan CENTRAL PARK    11528
# 10  6090                      West Village Nest - Superhost    11975
# 11  6848                   Only 2 stops to Manhattan studio    15991
# 12  6990               UES Beautiful Blue Room / 2 Bedrooms    16800
# ...

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.

gb_nei = df.groupby('neighbourhood_group')['id'].count()
new_df = pd.DataFrame(gb_nei)

# %%
new_df.reset_index()
# Out:
#   neighbourhood_group     id
# 0               Bronx   1183
# 1            Brooklyn  18632
# 2           Manhattan  20580
# 3              Queens   5791
# 4       Staten Island    341

# %%
new_df = new_df.reset_index()

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 

gb = df.groupby('neighbourhood_group')['price'].mean()
#gb['price'].agg( ['count', 'min', 'max', 'mean', 'median', 'std', 'sum'] )
mean_price = pd.DataFrame(gb)

# %%
mean_price.reset_index()
# Out:
#   neighbourhood_group       price
# 0               Bronx   92.751479
# 1            Brooklyn  120.225258
# 2           Manhattan  191.880466
# 3              Queens   99.754965
# 4       Staten Island  110.947214

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 
gb2 = df.groupby('neighbourhood_group')['price'].max()
max_price = pd.DataFrame(gb2).reset_index()
max_price
# Out:
#   neighbourhood_group  price
# 0               Bronx   1404
# 1            Brooklyn  10000
# 2           Manhattan  10000
# 3              Queens  10000
# 4       Staten Island   1200

# %%
gb3 = df.groupby('neighbourhood_group')['price'].agg('min')
min_price = pd.DataFrame(gb3).reset_index()
min_price
# Out:
#   neighbourhood_group  price
# 0               Bronx     16
# 1            Brooklyn      0
# 2           Manhattan      0
# 3              Queens      0
# 4       Staten Island     19

# %%
gb3 = df.groupby('neighbourhood_group')['price'].agg(['min','max'])
min_max_price = pd.DataFrame(gb3).reset_index()
min_max_price
# Out:
#   neighbourhood_group  min    max
# 0               Bronx   16   1404
# 1            Brooklyn    0  10000
# 2           Manhattan    0  10000
# 3              Queens    0  10000
# 4       Staten Island   19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.
gb4 = df.groupby(['neighbourhood_group','room_type'])['price'].agg('mean')

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
gb6 = df.groupby(['neighbourhood_group','room_type'])
gb6['price'].agg('mean').reset_index()
# Out:
#    neighbourhood_group        room_type       price
# 0                Bronx  Entire home/apt  138.004819
# 1                Bronx     Private room   68.419668
# 2                Bronx      Shared room   66.391304
# 3             Brooklyn  Entire home/apt  171.587687
# 4             Brooklyn       Hotel room  147.300000
# 5             Brooklyn     Private room   71.291189
# 6             Brooklyn      Shared room   57.870091
# 7            Manhattan  Entire home/apt  231.335572
# 8            Manhattan       Hotel room  292.515670
# 9            Manhattan     Private room  128.277069
# 10           Manhattan      Shared room  111.735084
# 11              Queens  Entire home/apt  150.168900
# 12              Queens       Hotel room  139.058824
# 13              Queens     Private room   69.972564
# 14              Queens      Shared room   89.891892
# 15       Staten Island  Entire home/apt  151.720930
# 16       Staten Island     Private room   70.312883
# ...

# %%
new_df = pd.DataFrame(gb4).reset_index()
new_df
# Out:
#    neighbourhood_group        room_type       price
# 0                Bronx  Entire home/apt  138.004819
# 1                Bronx     Private room   68.419668
# 2                Bronx      Shared room   66.391304
# 3             Brooklyn  Entire home/apt  171.587687
# 4             Brooklyn       Hotel room  147.300000
# 5             Brooklyn     Private room   71.291189
# 6             Brooklyn      Shared room   57.870091
# 7            Manhattan  Entire home/apt  231.335572
# 8            Manhattan       Hotel room  292.515670
# 9            Manhattan     Private room  128.277069
# 10           Manhattan      Shared room  111.735084
# 11              Queens  Entire home/apt  150.168900
# 12              Queens       Hotel room  139.058824
# 13              Queens     Private room   69.972564
# 14              Queens      Shared room   89.891892
# 15       Staten Island  Entire home/apt  151.720930
# 16       Staten Island     Private room   70.312883
# ...

# %%
# Changing price column name
new_df.rename(columns={"price": "mean_price"},inplace = True)
new_df
# Out:
#    neighbourhood_group        room_type  mean_price
# 0                Bronx  Entire home/apt  138.004819
# 1                Bronx     Private room   68.419668
# 2                Bronx      Shared room   66.391304
# 3             Brooklyn  Entire home/apt  171.587687
# 4             Brooklyn       Hotel room  147.300000
# 5             Brooklyn     Private room   71.291189
# 6             Brooklyn      Shared room   57.870091
# 7            Manhattan  Entire home/apt  231.335572
# 8            Manhattan       Hotel room  292.515670
# 9            Manhattan     Private room  128.277069
# 10           Manhattan      Shared room  111.735084
# 11              Queens  Entire home/apt  150.168900
# 12              Queens       Hotel room  139.058824
# 13              Queens     Private room   69.972564
# 14              Queens      Shared room   89.891892
# 15       Staten Island  Entire home/apt  151.720930
# 16       Staten Island     Private room   70.312883
# ...

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.

gb6['price'].agg(['count', 'min', 'max', 'mean', 'median', 'std', 'sum']).reset_index()
# Out:
#    neighbourhood_group        room_type  count  min    max        mean  \
# 0                Bronx  Entire home/apt    415   25   1404  138.004819
# 1                Bronx     Private room    722   16    700   68.419668
# 2                Bronx      Shared room     46   20    800   66.391304
# 3             Brooklyn  Entire home/apt   9112   20  10000  171.587687
# 4             Brooklyn       Hotel room     30    0    399  147.300000
# 5             Brooklyn     Private room   9159   10   2500   71.291189
# 6             Brooklyn      Shared room    331   15   1500   57.870091
# 7            Manhattan  Entire home/apt  12209    0  10000  231.335572
# 8            Manhattan       Hotel room    351    0   2211  292.515670
# 9            Manhattan     Private room   7601   10  10000  128.277069
# 10           Manhattan      Shared room    419   10  10000  111.735084
# 11              Queens  Entire home/apt   2090   10  10000  150.168900
# ...

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
df_prices = pd.read_csv('Data/prices.csv')
df_prices.head()
# Out:
#   neighbourhood_group   mean_price
# 0               Bronx    92.751479
# 1            Brooklyn   120.225258
# 2           Manhattan   191.880466
# 3              Queens    99.754965
# 4       Staten Island   110.947214

# %%
df_n_listings = pd.read_csv('Data/n_listings.csv', sep = ';')
df_n_listings.head()
# Out:
#   neighbourhood_group  n_listings
# 0               Bronx        1183
# 1            Brooklyn       18632
# 2           Manhattan       20580
# 3          LongIsland        4121

# %%
# 2. Do join that keeps all the records for each table.

new_df = pd.merge(df_prices, df_n_listings, on='neighbourhood_group')
new_df
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx    92.751479        1183
# 1            Brooklyn   120.225258       18632
# 2           Manhattan   191.880466       20580

# %%
dfjoined = pd.merge(df_prices, df_n_listings, on='neighbourhood_group', how='outer')
dfjoined
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx    92.751479      1183.0
# 1            Brooklyn   120.225258     18632.0
# 2           Manhattan   191.880466     20580.0
# 3              Queens    99.754965         NaN
# 4       Staten Island   110.947214         NaN
# 5          LongIsland          NaN      4121.0

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
#  1. Who was won Album of the Year in 2016?

df_gram = pd.read_csv('Data/grammys.csv')
df_gram.head()
# Out:
#    year                                           category  \
# 0  1959                                  Album of the Year
# 1  1959                                   Best Album Cover
# 2  1959                                   Best Arrangement
# 3  1959  Best Classical Performance - Chamber Music (in...
# 4  1959  Best Classical Performance - Instrumentalist (...
#
#                       nominee  \
# 0  The Music from Peter Gunn.
# 1             Only the Lonely
# 2   The Music From Peter Gunn
# 3      Beethoven: Quartet 130
# 4      Segovia Golden Jubilee
#
#                                              workers  winner
# 0                                      Henry Mancini    True
# 1                       Frank Sinatra (art director)    True
# 2                    Henry Mancini (artist/arranger)    True
# 3  The Hollywood String Quartet, Paul Shure (arti...    True
# 4                                     Andrés Segovia    True

# %%
# 2. Who won Best Rap Album in 2009?
c1 = df_gram['category'] == 'Best Rap Album'
c2 = df_gram['year'] == 2009
c3 = df_gram['winner'] == True
#select_statement = df['private_room_in_williamsburg'] == 1
#df['private_room_in_williamsburg'] =  np.where( c1 & c2, 1, 0 )
df_gram['Best Rap 2009'] =  np.where( c1 & c2 & c3, 1, 0 )

select_statement = df_gram['Best Rap 2009'] == 1
df_gram[select_statement]
# Out:
#       year        category         nominee     workers  winner  Best Rap 2009
# 4396  2009  Best Rap Album  Tha Carter III  Lil' Wayne    True              1

# %%
def best_rap(year):
    c1 = 'Best Rap Album'
    c2 = year

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

c4 = df_gram['nominee'] == 'Kendrick Lamar'
df_gram[c4]
# Out:
#       year         category         nominee workers  winner  Best Rap 2009
# 5246  2014  Best New Artist  Kendrick Lamar     NaN   False              0

# %%
! open .
